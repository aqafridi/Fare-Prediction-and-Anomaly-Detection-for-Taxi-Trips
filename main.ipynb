# %%
import pandas as pd
df = pd.read_csv('2021_Yellow_Taxi_Trip_Data_20240406.csv')
# Out:
# C:\Users\Qadeer\AppData\Local\Temp\ipykernel_7976\1691626393.py:2: DtypeWarning: Columns (0,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('2021_Yellow_Taxi_Trip_Data_20240406.csv')

# %%
# Check the first few rows
df.head()
# Out:
#   VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  passenger_count  \
# 0        1  01/01/2021 12:30:10 AM  01/01/2021 12:36:12 AM              1.0
# 1        1  01/01/2021 12:51:20 AM  01/01/2021 12:52:19 AM              1.0
# 2        1  01/01/2021 12:43:30 AM  01/01/2021 01:11:06 AM              1.0
# 3        1  01/01/2021 12:15:48 AM  01/01/2021 12:31:01 AM              0.0
# 4        2  01/01/2021 12:31:49 AM  01/01/2021 12:48:21 AM              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.10         1.0                  N         142.0          43.0
# 1           0.20         1.0                  N         238.0         151.0
# 2          14.70         1.0                  N         132.0         165.0
# 3          10.60         1.0                  N         138.0         132.0
# 4           4.94         1.0                  N          68.0          33.0
#
# ...

# %%
# Examine the column names and data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5179671 entries, 0 to 5179670
# Data columns (total 18 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               object
#  1   tpep_pickup_datetime   object
#  2   tpep_dropoff_datetime  object
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           float64
#  8   DOLocationID           float64
#  9   payment_type           float64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
# dtypes: float64(14), object(4)
# memory usage: 711.3+ MB

# %%
# Summarize the numerical features
df.describe()
# Out:
#        passenger_count  trip_distance    RatecodeID  PULocationID  \
# count     4.855148e+06   5.179666e+06  4.855148e+06  5.179666e+06
# mean      1.407343e+00   4.263697e+00  1.032661e+00  1.659054e+02
# std       1.043737e+00   3.811088e+02  5.714004e-01  6.776109e+01
# min       0.000000e+00   0.000000e+00  1.000000e+00  1.000000e+00
# 25%       1.000000e+00   1.000000e+00  1.000000e+00  1.250000e+02
# 50%       1.000000e+00   1.700000e+00  1.000000e+00  1.620000e+02
# 75%       1.000000e+00   3.000000e+00  1.000000e+00  2.360000e+02
# max       9.000000e+00   2.631633e+05  9.900000e+01  2.650000e+02
#
#        DOLocationID  payment_type   fare_amount         extra       mta_tax  \
# count  5.179666e+06  4.855148e+06  5.179666e+06  5.179666e+06  5.179666e+06
# mean   1.621669e+02  1.271357e+00  1.218247e+01  1.042508e+00  4.931322e-01
# std    7.176997e+01  4.866569e-01  1.755228e+02  1.250072e+00  7.597929e-02
# ...

# %%
# Check for missing values
df.isnull().sum()
# Out:
# VendorID                 324518
# tpep_pickup_datetime          4
# tpep_dropoff_datetime         5
# passenger_count          324523
# trip_distance                 5
# RatecodeID               324523
# store_and_fwd_flag       324523
# PULocationID                  5
# DOLocationID                  5
# payment_type             324523
# fare_amount                   5
# extra                         5
# mta_tax                       5
# tip_amount                    5
# tolls_amount                  5
# improvement_surcharge         5
# total_amount                  5
# congestion_surcharge          5
# dtype: int64

# %%
# Drop rows with missing values (if the number of missing values is small)
df = df.dropna()

# # Alternatively, fill the missing values with a suitable strategy
# df['feature_with_missing'] = df['feature_with_missing'].fillna(df['feature_with_missing'].mean())
